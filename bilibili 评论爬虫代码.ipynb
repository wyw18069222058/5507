# %%
import requests 
import pandas as pd  
import json

# %%
def bv2av(bid):
    table='fZodR9XQDSUm21yCkr6zBqiveYah8bt4xsWpHnJE7jL5VG3guMTKNPAwcF'
    tr={}
    for i in range(58):
        tr[table[i]]=i
    s=[11,10,3,8,4,6]
    r=0
    for i in range(6):
        r+=tr[bid[s[i]]]*58**i
    aid=(r-8728348608)^177451812
    return aid

# %%
def get_comment(v_aid,v_bid):
    headers = {
    'authority': 'api.bilibili.com',
    'accept': '*/*',
    'accept-language': 'zh-CN,zh;q=0.9',
    'cookie': "buvid3=ABD7A889-74DB-A334-6E6F-8F28E3E43BDB09033infoc; b_nut=1694240509; i-wanna-go-back=-1; b_ut=7; _uuid=57F4A1019-6897-831A-6622-26CE8D66EBDB12349infoc; buvid4=9A6FB2B1-A22C-5995-82E6-DB0E8AC837A210848-023090914-qsrdsD%2FbxDVqfMWKU%2BgRcA%3D%3D; CURRENT_FNVAL=4048; rpdid=|(u|kRRR))kk0J'uYmRkR|lkJ; DedeUserID=102144589; DedeUserID__ckMd5=f3ce9403ecfcbb8b; CURRENT_QUALITY=80; LIVE_BUVID=AUTO8116942677751283; buvid_fp_plain=undefined; enable_web_push=DISABLE; header_theme_version=CLOSE; fingerprint=d0b3d6426a036aa894a5b1288bde2b6a; buvid_fp=d0b3d6426a036aa894a5b1288bde2b6a; PVID=4; bili_ticket=eyJhbGciOiJIUzI1NiIsImtpZCI6InMwMyIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3MDA2MjM4NjEsImlhdCI6MTcwMDM2NDYwMSwicGx0IjotMX0.8pwtIqsWJUTqaF9RZoPbKqzuvsJjgOp0tBMrPHr3jyA; bili_ticket_expires=1700623801; bp_video_offset_102144589=865679872905707520; SESSDATA=1a68bd72%2C1716097525%2Cab61a%2Ab2CjBqE3pDG8pNzM6BzVqPjK6sJ9yJ3xnH-56SkMnUb2LUtL1uZK6VqEgBNzhWE9t9uf4SVi1kZ2tGUm0zcC1wcDFIc0xLRHpzVDZrWVFjTFlQdVZxREMwdTl2TVpBUURwNUxRTXNYdHJ6ZmtIWFRLVTB4MWxvTmFqVUNnYWxJcVJOc0psb2ZaT0JRIIEC; bili_jct=d0a2a2a21a5b920d0ad6b5bfc3d4d4e5; b_lsid=FF4E5F79_18BF184C9EC; home_feed_column=5; browser_resolution=1707-932; sid=7a5vefif",
    'origin': 'https://www.bilibili.com',
    'referer': 'https://www.bilibili.com/video/BV1yP411y7Cx/?spm_id_from=333.999.0.0&vd_source=972ceee0b709ec425b13a5e2b369e640',
    'sec-ch-ua': '"Google Chrome";v="119", "Chromium";v="119", "Not?A_Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36'
    } 
    url="https://api.bilibili.com/x/v2/reply/wbi/main?oid=230295861&type=1&mode=3&pagination_str=%7B%22offset%22:%22%7B%5C%22type%5C%22:1,%5C%22direction%5C%22:1,%5C%22session_id%5C%22:%5C%221741382648164413%5C%22,%5C%22data%5C%22:%7B%7D%7D%22%7D&plat=1&web_location=1315875&w_rid=8bbe4c77ee09b64cc000a81fb7c92c63&wts=1700569002"
    response = requests.get(url, headers = headers, )
    data_list=response.json()['data']['replies']
    comment_list = []  # 评论内容空列表
# 循环爬取每一条评论数据
    for a in data_list:
        # 评论内容
        comment = a['content']['message']
        comment_list.append(comment)
    user_list = []  # 评论者空列表
    # 循环爬取每一条评论数据
    for a in data_list:
        # 评论内容
        user = a['member']['uname']
        user_list.append(user)
    like_list = []  # 评论内容空列表
    # 循环爬取每一条评论数据
    for a in data_list:
        # 评论内容
        like = a['like']
        like_list.append(like)
    # 把列表拼装为DataFrame数据
    df = pd.DataFrame({
        '评论作者': user_list,
        '点赞数': like_list,
        '评论内容': comment_list,
    })
    # 把评论数据保存到csv文件
    df.to_csv(outfile, mode='a+', encoding='utf_8_sig', index=False)

# %%
bid_list=["BV1Fh411N7gw"]
for bid in bid_list:
    outfile='成都面食.csv'
    aid=bv2av(bid=bid)
    get_comment(v_aid=aid,v_bid=bid)

# %%
df=pd.read_csv('成都面食.csv')

# %%
df.head(20)
# Out:
#                 评论作者  点赞数                                               评论内容
# 0            大铁锅炖白头鹰    0  关于面条是起源于意大利还是中国，只要意大利能拿出四千年前出土的面条，这个起源就归意大利了[d...
# 1               卡弥撒蛮    0                          担担面、甜水面、素椒杂酱、鸡杂面、铺盖面都是好吃的
# 2                几只船    0                                 我们一起去红星路的自力面馆吧[点赞]
# 3   bili_81348269082    0                        铺盖面好吃原味儿炸酱的才好吃，然后我们这儿才七块钱一碗
# 4           tchj8466    1                             成都蹄花面，肥肠粉都很好吃，甜水面有点吃不来
# 5           Jerry696    0                                    Jack中文进步神速啊语言天才
# 6            baridcd    0                                     哼 成都的面就是好吃[抓狂]
# 7               三叁彡弎    1                                       推荐豌杂面，豌豆真的好吃
# 8              逆天丶狂少    1                                       甜水面确实适合欧美的甜口
# 9               牌坊大人    0               but I prefer Chongqing 豌杂面，老麻抄手，万州小面
# 10            hi上校先生    0  Your videos are fairly good [打call][打call][打call]
# ...
