# %%
import pandas as pd
import googleapiclient.discovery

# %%
API_KEY = 'AIzaSyBrUsFwgTTXMeV0XnqT5E4z0GAdgEb1RgI'

# %%
pip install --upgrade google-api-python-client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
API_SERVICE_NAME = "youtube"
API_VERSION= "v3"

# %%
VIDEO_ID = 'VA6mHcr3dYs'

# %%
youtube = googleapiclient.discovery.build(
    API_SERVICE_NAME, API_VERSION, developerKey = API_KEY)

request = youtube.commentThreads().list(
    part="snippet,replies",
    videoId=VIDEO_ID,
    maxResults=100
    )
response = request.execute()

# %%
response['items'][2]['snippet']['topLevelComment']['snippet']['textOriginal']
# Out:
# 'British English and my hometown.'

# %%
df = pd.json_normalize(response['items'])

# %%
df.head()
# Out:
#                     kind                         etag  \
# 0  youtube#commentThread  QnXvZ-OsvfIfY6Uzs9BYDF2yWRw
# 1  youtube#commentThread  8FjhsPwVNQR1ntcz7gtJoKBXsiE
# 2  youtube#commentThread  B4fHLtObFdFA9eTD_qybAKSc-jE
# 3  youtube#commentThread  msxsmvC1RAplwC5ZWYXjXnjUHdM
# 4  youtube#commentThread  fB3lJ4f_1X4oNYZ23S3_pSLGj9g
#
#                            id         snippet.channelId snippet.videoId  \
# 0  Ugywqfhjp8AJm06MOYl4AaABAg  UC1XG7bJnYqta_ezr12WZp7w     VA6mHcr3dYs
# 1  Ugz3wXtRmHfhA6c2v2N4AaABAg  UC1XG7bJnYqta_ezr12WZp7w     VA6mHcr3dYs
# 2  UgwVPepPYLgUfYxuJQZ4AaABAg  UC1XG7bJnYqta_ezr12WZp7w     VA6mHcr3dYs
# 3  UgwWfu8_2JVYnvt2QRp4AaABAg  UC1XG7bJnYqta_ezr12WZp7w     VA6mHcr3dYs
# 4  Ugx1pQvyQirCbsOLW0B4AaABAg  UC1XG7bJnYqta_ezr12WZp7w     VA6mHcr3dYs
#
#   snippet.topLevelComment.kind snippet.topLevelComment.etag  \
# 0              youtube#comment  xCu4VGUwtOiOaUbrPhdKDyFTJ1c
# 1              youtube#comment  tzBVu90SM0y279HP_ebYSjsMCp0
# ...

# %%
df.columns
# Out:
# Index(['kind', 'etag', 'id', 'snippet.channelId', 'snippet.videoId',
#        'snippet.topLevelComment.kind', 'snippet.topLevelComment.etag',
#        'snippet.topLevelComment.id',
#        'snippet.topLevelComment.snippet.channelId',
#        'snippet.topLevelComment.snippet.videoId',
#        'snippet.topLevelComment.snippet.textDisplay',
#        'snippet.topLevelComment.snippet.textOriginal',
#        'snippet.topLevelComment.snippet.authorDisplayName',
#        'snippet.topLevelComment.snippet.authorProfileImageUrl',
#        'snippet.topLevelComment.snippet.authorChannelUrl',
#        'snippet.topLevelComment.snippet.authorChannelId.value',
#        'snippet.topLevelComment.snippet.canRate',
#        'snippet.topLevelComment.snippet.viewerRating',
#        'snippet.topLevelComment.snippet.likeCount',
#        'snippet.topLevelComment.snippet.publishedAt',
#        'snippet.topLevelComment.snippet.updatedAt', 'snippet.canReply',
# ...

# %%
df.columns = df.columns.str.removeprefix('snippet.topLevelComment.').str.removeprefix('snippet.').str.removesuffix('.value').str.removesuffix('.comments')

# %%
df.head()
# Out:
#                     kind                         etag  \
# 0  youtube#commentThread  QnXvZ-OsvfIfY6Uzs9BYDF2yWRw
# 1  youtube#commentThread  8FjhsPwVNQR1ntcz7gtJoKBXsiE
# 2  youtube#commentThread  B4fHLtObFdFA9eTD_qybAKSc-jE
# 3  youtube#commentThread  msxsmvC1RAplwC5ZWYXjXnjUHdM
# 4  youtube#commentThread  fB3lJ4f_1X4oNYZ23S3_pSLGj9g
#
#                            id                 channelId      videoId  \
# 0  Ugywqfhjp8AJm06MOYl4AaABAg  UC1XG7bJnYqta_ezr12WZp7w  VA6mHcr3dYs
# 1  Ugz3wXtRmHfhA6c2v2N4AaABAg  UC1XG7bJnYqta_ezr12WZp7w  VA6mHcr3dYs
# 2  UgwVPepPYLgUfYxuJQZ4AaABAg  UC1XG7bJnYqta_ezr12WZp7w  VA6mHcr3dYs
# 3  UgwWfu8_2JVYnvt2QRp4AaABAg  UC1XG7bJnYqta_ezr12WZp7w  VA6mHcr3dYs
# 4  Ugx1pQvyQirCbsOLW0B4AaABAg  UC1XG7bJnYqta_ezr12WZp7w  VA6mHcr3dYs
#
#               kind                         etag                          id  \
# 0  youtube#comment  xCu4VGUwtOiOaUbrPhdKDyFTJ1c  Ugywqfhjp8AJm06MOYl4AaABAg
# ...

# %%
df.to_csv(f'comments-{VIDEO_ID}.csv',index=False)
